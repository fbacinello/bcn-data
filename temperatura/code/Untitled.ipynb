# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/temperaturesbarcelonadesde1780.csv')
data_long = pd.read_csv('../data/temperaturesbarcelonadesde1780_format_long.csv')

# %%
data
# Out:
#       Any  Temp_Mitjana_Gener  Temp_Mitjana_Febrer  Temp_Mitjana_Marc  \
# 0    1780                 6.7                  7.3               11.6
# 1    1781                 7.5                  8.9               10.9
# 2    1782                 8.2                  6.1                9.8
# 3    1783                 8.3                  8.6                9.6
# 4    1784                 7.3                  7.1               10.8
# 5    1785                 9.0                  6.4                7.9
# 6    1786                 7.8                  8.3                9.9
# 7    1787                 5.4                  7.8               11.3
# 8    1788                 6.4                 10.1               10.4
# 9    1789                 6.9                  9.3                8.7
# 10   1790                 7.4                  9.5               10.4
# 11   1791                 9.5                  6.9               11.1
# ...

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data['Any'], data['Temp_Mitjana_Agost'])

# %%
temp_agos = data['Temp_Mitjana_Agost']

print 'Año con mayor temperatura en agosto:', int(data.loc[data['Temp_Mitjana_Agost'].idxmax].Any)
print 'Temperatura media: ', max(data['Temp_Mitjana_Agost'])
# Out:
# Año con mayor temperatura en agosto: 2003
# Temperatura media:  28.5

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data['Any'], data['Temp_Mitjana_Gener'])
